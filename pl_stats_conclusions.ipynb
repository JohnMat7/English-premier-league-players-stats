# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('EPL_20_21.csv')

# %%
chelsea_players = df[df.Club == "Chelsea"]
chelsea_players
# Out:
#                    Name     Club Nationality Position  Age  Matches  Starts  \
# 0           Mason Mount  Chelsea         ENG    MF,FW   21       36      32
# 1         Edouard Mendy  Chelsea         SEN       GK   28       31      31
# 2           Timo Werner  Chelsea         GER       FW   24       35      29
# 3          Ben Chilwell  Chelsea         ENG       DF   23       27      27
# 4           Reece James  Chelsea         ENG       DF   20       32      25
# 5     César Azpilicueta  Chelsea         ESP       DF   30       26      24
# 6          N'Golo Kanté  Chelsea         FRA       MF   29       30      24
# 7              Jorginho  Chelsea         ITA       MF   28       28      23
# 8          Thiago Silva  Chelsea         BRA       DF   35       23      23
# 9            Kurt Zouma  Chelsea         FRA       DF   25       24      22
# 10        Mateo Kovačić  Chelsea         CRO       MF   26       27      21
# ...

# %%
chelsea_players
# Out:
#                    Name     Club Nationality Position  Age  Matches  Starts  \
# 0           Mason Mount  Chelsea         ENG    MF,FW   21       36      32
# 1         Edouard Mendy  Chelsea         SEN       GK   28       31      31
# 2           Timo Werner  Chelsea         GER       FW   24       35      29
# 3          Ben Chilwell  Chelsea         ENG       DF   23       27      27
# 4           Reece James  Chelsea         ENG       DF   20       32      25
# 5     César Azpilicueta  Chelsea         ESP       DF   30       26      24
# 6          N'Golo Kanté  Chelsea         FRA       MF   29       30      24
# 7              Jorginho  Chelsea         ITA       MF   28       28      23
# 8          Thiago Silva  Chelsea         BRA       DF   35       23      23
# 9            Kurt Zouma  Chelsea         FRA       DF   25       24      22
# 10        Mateo Kovačić  Chelsea         CRO       MF   26       27      21
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 532 entries, 0 to 531
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   532 non-null    object
#  1   Club                   532 non-null    object
#  2   Nationality            532 non-null    object
#  3   Position               532 non-null    object
#  4   Age                    532 non-null    int64
#  5   Matches                532 non-null    int64
#  6   Starts                 532 non-null    int64
#  7   Mins                   532 non-null    int64
#  8   Goals                  532 non-null    int64
#  9   Assists                532 non-null    int64
#  10  Passes_Attempted       532 non-null    int64
#  11  Perc_Passes_Completed  532 non-null    float64
#  12  Penalty_Goals          532 non-null    int64
#  13  Penalty_Attempted      532 non-null    int64
# ...

# %%
df.describe()
# Out:
#               Age     Matches      Starts         Mins       Goals  \
# count  532.000000  532.000000  532.000000   532.000000  532.000000
# mean    25.500000   19.535714   15.714286  1411.443609    1.853383
# std      4.319404   11.840459   11.921161  1043.171856    3.338009
# min     16.000000    1.000000    0.000000     1.000000    0.000000
# 25%     22.000000    9.000000    4.000000   426.000000    0.000000
# 50%     26.000000   21.000000   15.000000  1345.000000    1.000000
# 75%     29.000000   30.000000   27.000000  2303.500000    2.000000
# max     38.000000   38.000000   38.000000  3420.000000   23.000000
#
#           Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# count  532.000000        532.000000             532.000000     532.000000
# mean     1.287594        717.750000              77.823872       0.191729
# std      2.095191        631.372522              13.011631       0.850881
# ...

# %%
df.describe().transpose()
# Out:
#                        count         mean          std   min     25%      50%  \
# Age                    532.0    25.500000     4.319404  16.0   22.00    26.00
# Matches                532.0    19.535714    11.840459   1.0    9.00    21.00
# Starts                 532.0    15.714286    11.921161   0.0    4.00    15.00
# Mins                   532.0  1411.443609  1043.171856   1.0  426.00  1345.00
# Goals                  532.0     1.853383     3.338009   0.0    0.00     1.00
# Assists                532.0     1.287594     2.095191   0.0    0.00     0.00
# Passes_Attempted       532.0   717.750000   631.372522   0.0  171.50   573.50
# Perc_Passes_Completed  532.0    77.823872    13.011631  -1.0   73.50    79.20
# Penalty_Goals          532.0     0.191729     0.850881   0.0    0.00     0.00
# Penalty_Attempted      532.0     0.234962     0.975818   0.0    0.00     0.00
# xG                     532.0     0.113289     0.148174   0.0    0.01     0.06
# ...

# %%
df.isnull().sum()
# Out:
# Name                     0
# Club                     0
# Nationality              0
# Position                 0
# Age                      0
# Matches                  0
# Starts                   0
# Mins                     0
# Goals                    0
# Assists                  0
# Passes_Attempted         0
# Perc_Passes_Completed    0
# Penalty_Goals            0
# Penalty_Attempted        0
# xG                       0
# xA                       0
# Yellow_Cards             0
# Red_Cards                0
# dtype: int64

# %%
df['MinsPerMatch'] = (df['Mins']/df['Matches'])
df
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 0          Mason Mount           Chelsea         ENG    MF,FW   21       36
# 1        Edouard Mendy           Chelsea         SEN       GK   28       31
# 2          Timo Werner           Chelsea         GER       FW   24       35
# 3         Ben Chilwell           Chelsea         ENG       DF   23       27
# 4          Reece James           Chelsea         ENG       DF   20       32
# ..                 ...               ...         ...      ...  ...      ...
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    DF,FW   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
# ...

# %%
df['Goals_Per_Match'] = (df['Goals']/df['Matches']).astype('float')
df
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 0          Mason Mount           Chelsea         ENG    MF,FW   21       36
# 1        Edouard Mendy           Chelsea         SEN       GK   28       31
# 2          Timo Werner           Chelsea         GER       FW   24       35
# 3         Ben Chilwell           Chelsea         ENG       DF   23       27
# 4          Reece James           Chelsea         ENG       DF   20       32
# ..                 ...               ...         ...      ...  ...      ...
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    DF,FW   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
# ...

# %%
df.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
# ...

# %%
#total goals in priemier league
total_goals = df['Goals'].sum()
total_goals
# Out:
# 986

# %%
#penalty goals

total_penalties_goals = df['Penalty_Goals'].sum()
total_penalties_goals
# Out:
# 102

# %%
#non-penalty
total_goals - total_penalties_goals
# Out:
# 884

# %%
#penalties-attempted
total_penalties_attempted = df['Penalty_Attempted'].sum()
total_penalties_attempted
# Out:
# 125

# %%
total_penalties_miss = total_penalties_attempted - total_penalties_goals
total_penalties_miss
# Out:
# 23

# %% [markdown]
# # Pie chart of Penalties Scored and missed

# %%
from matplotlib import style
  
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(7,6))
data = [total_penalties_miss,total_penalties_goals]
labels = ['Penalties Missed','Penalties Scored']
colors = sns.color_palette('bright')
plt.pie(data,labels = labels,colors = colors , autopct = '%.2f%%')
plt.show()

# %%
df['Position'].unique()
# Out:
# array(['MF,FW', 'GK', 'FW', 'DF', 'MF', 'FW,MF', 'FW,DF', 'DF,MF',
#        'MF,DF', 'DF,FW'], dtype=object)

# %%
colors = sns.color_palette("bright")
plt.figure(figsize=(7,6))
plt.title('Total Players with position Groups', fontsize = 20)
df['Position'].value_counts().plot(kind='pie',colors = colors,autopct="%.01f%%")
# Out:
# <AxesSubplot:title={'center':'Total Players with position Groups'}, ylabel='Position'>

# %%
df[df['Position'] == 'FW'].sort_index(axis=0)
# Out:
#                    Name              Club Nationality Position  Age  Matches  \
# 2           Timo Werner           Chelsea         GER       FW   24       35
# 16        Tammy Abraham           Chelsea         ENG       FW   22       22
# 19       Olivier Giroud           Chelsea         FRA       FW   33       17
# 23   Ruben Loftus-Cheek           Chelsea         ENG       FW   24        1
# 30      Raheem Sterling   Manchester City         ENG       FW   25       31
# ..                  ...               ...         ...      ...  ...      ...
# 516        Oliver Burke  Sheffield United         SCO       FW   23       25
# 518     Oliver McBurnie  Sheffield United         SCO       FW   24       23
# 519      Rhian Brewster  Sheffield United         ENG       FW   20       27
# 523         Billy Sharp  Sheffield United         ENG       FW   34       16
# 526     Daniel Jebbison  Sheffield United         ENG       FW   17        4
#
# ...

# %%
original_sheet = df

# %%
original_sheet.describe()
# Out:
#               Age     Matches      Starts         Mins       Goals  \
# count  532.000000  532.000000  532.000000   532.000000  532.000000
# mean    25.500000   19.535714   15.714286  1411.443609    1.853383
# std      4.319404   11.840459   11.921161  1043.171856    3.338009
# min     16.000000    1.000000    0.000000     1.000000    0.000000
# 25%     22.000000    9.000000    4.000000   426.000000    0.000000
# 50%     26.000000   21.000000   15.000000  1345.000000    1.000000
# 75%     29.000000   30.000000   27.000000  2303.500000    2.000000
# max     38.000000   38.000000   38.000000  3420.000000   23.000000
#
#           Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# count  532.000000        532.000000             532.000000     532.000000
# mean     1.287594        717.750000              77.823872       0.191729
# std      2.095191        631.372522              13.011631       0.850881
# ...

# %%
np.size(df['Nationality'].unique())
# Out:
# 59

# %%
np.size(df['Position'].unique())
# Out:
# 10

# %% [markdown]
# ##  most nationalities in epl

# %%
df['Nationality'].value_counts()
# Out:
# ENG    192
# FRA     31
# BRA     27
# ESP     26
# POR     21
# IRL     21
# SCO     20
# NED     16
# WAL     12
# BEL     11
# GER      9
# ARG      8
# CIV      8
# NGA      7
# USA      6
# SUI      6
# DEN      6
# EGY      5
# SWE      5
# POL      5
# NIR      5
# SEN      5
# COL      5
# GHA      5
# ITA      5
# TUR      5
# SRB      4
# AUS      4
# JAM      3
# NOR      3
# ALG      3
# CZE      3
# ISL      3
# JPN      2
# SVK      2
# CMR      2
# COD      2
# PAR      2
# UKR      2
# CRO      2
# GAB      2
# MLI      2
# RSA      2
# MAR      2
# ZIM      1
# IRN      1
# MEX      1
# MKD      1
# BIH      1
# SKN      1
# GUI      1
# CAN      1
# NZL      1
# URU      1
# BFA      1
# AUT      1
# KOR      1
# GRE      1
# MTN      1
# Name: Nationality, dtype: int64

# %%
nationality = df.groupby('Nationality').size().sort_values(ascending = False)
nationality.head(15).plot(kind='bar',figsize=(13,6),color = sns.color_palette("bright"))
# Out:
# <AxesSubplot:xlabel='Nationality'>

# %%
#total players in each club
df['Club'].value_counts()
# Out:
# West Bromwich Albion       30
# Southampton                29
# Manchester United          29
# Arsenal                    29
# Everton                    29
# Fulham                     28
# Liverpool FC               28
# Leicester City             27
# Chelsea                    27
# Sheffield United           27
# Wolverhampton Wanderers    27
# Brighton                   27
# Newcastle United           27
# Burnley                    25
# Tottenham Hotspur          24
# West Ham United            24
# Manchester City            24
# Crystal Palace             24
# Aston Villa                24
# Leeds United               23
# Name: Club, dtype: int64

# %%
df['Club'].value_counts().head(10).plot(kind='bar',color=sns.color_palette('viridis'))
# Out:
# <AxesSubplot:>

# %%
top_gs = df.groupby(['Name'])['Goals'].sum().sort_values(ascending=False).head(15)
# df.groupby(['Goals'])['Name'].sum()
plt.xlabel("Goals")
plt.ylabel("Players")
top_gs.plot(kind='bar', color = sns.color_palette("bright"))
plt.ylabel("Goals")
plt.xlabel("Players")
# Out:
# Text(0.5, 0, 'Players')

# %%
df.head(5)
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
# ...

# %%
# age_under_20 = df[df['Age']<=20]
age_under_20 = df[df['Age']<=20]
age_20_25 = df[(df['Age']>20) & (df['Age']<=25)]
age_25_30 = df[(df['Age']>25) & (df['Age']<=30)]
age_above_30 = df[df['Age']>30]

# %% [markdown]
# ## total_players with age groups

# %%
age_data = [age_under_20['Name'].count(),age_20_25['Name'].count(),age_25_30['Name'].count(),age_above_30['Name'].count()]
labels = ["<=20" , "20-25","25-30","30+"] 
colors = sns.color_palette("bright")
plt.title('Total Player with different age group',fontsize=20)
plt.pie(age_data , labels = labels , colors = colors , autopct = "%.1f%%")
plt.show()

# %%
df[df['Age']>35]
# Out:
#                    Name                  Club Nationality Position  Age  \
# 22      Willy Caballero               Chelsea         ARG       GK   38
# 133          Wes Morgan        Leicester City         JAM       DF   36
# 493  Branislav Ivanović  West Bromwich Albion         SRB       DF   36
# 525       Phil Jagielka      Sheffield United         ENG       DF   37
#
#      Matches  Starts  Mins  Goals  Assists  Passes_Attempted  \
# 22         1       1    90      0        0                26
# 133        3       0    18      0        0                 5
# 493       13       8   767      0        0               311
# 525       10       6   526      0        0               186
#
#      Perc_Passes_Completed  Penalty_Goals  Penalty_Attempted    xG    xA  \
# 22                    92.3              0                  0  0.00  0.00
# 133                  100.0              0                  0  0.00  0.00
# 493                   85.2              0                  0  0.06  0.01
# ...

# %%
df[df['Age'] == df['Age'].max()]
df[df['Age'] == df['Age'].min()]
# df['Age'].max()
# Out:
#                    Name               Club Nationality Position  Age  Matches  \
# 76      Shola Shoretire  Manchester United         ENG       FW   16        2
# 182       Dane Scarlett  Tottenham Hotspur         ENG       FW   16        1
# 284  Carney Chukwuemeka        Aston Villa         ENG    FW,MF   16        2
# 530   Antwoine Hackford   Sheffield United         ENG    DF,FW   16        1
#
#      Starts  Mins  Goals  Assists  Passes_Attempted  Perc_Passes_Completed  \
# 76        0    11      0        0                 8                   75.0
# 182       0     1      0        0                 0                   -1.0
# 284       0    20      0        0                 8                   62.5
# 530       0    11      0        0                 1                  100.0
#
#      Penalty_Goals  Penalty_Attempted    xG   xA  Yellow_Cards  Red_Cards  \
# 76               0                  0  0.00  0.0             0          0
# ...

# %%
df[['Name','Age']]
# Out:
#                   Name  Age
# 0          Mason Mount   21
# 1        Edouard Mendy   28
# 2          Timo Werner   24
# 3         Ben Chilwell   23
# 4          Reece James   20
# ..                 ...  ...
# 527        Lys Mousset   24
# 528     Jack O'Connell   26
# 529      Iliman Ndiaye   21
# 530  Antwoine Hackford   16
# 531        Femi Seriki   17
#
# [532 rows x 2 columns]

# %%
df[df['Age'] == df['Age'].min()]
# Out:
#                    Name               Club Nationality Position  Age  Matches  \
# 76      Shola Shoretire  Manchester United         ENG       FW   16        2
# 182       Dane Scarlett  Tottenham Hotspur         ENG       FW   16        1
# 284  Carney Chukwuemeka        Aston Villa         ENG    FW,MF   16        2
# 530   Antwoine Hackford   Sheffield United         ENG    DF,FW   16        1
#
#      Starts  Mins  Goals  Assists  Passes_Attempted  Perc_Passes_Completed  \
# 76        0    11      0        0                 8                   75.0
# 182       0     1      0        0                 0                   -1.0
# 284       0    20      0        0                 8                   62.5
# 530       0    11      0        0                 1                  100.0
#
#      Penalty_Goals  Penalty_Attempted    xG   xA  Yellow_Cards  Red_Cards  \
# 76               0                  0  0.00  0.0             0          0
# ...

# %%
players_under_20 = df[df['Age']<20]
players_under_20['Club'].value_counts().plot(kind='bar',color = sns.color_palette('viridis'))
plt.ylabel('Amount of Players')
plt.xlabel('Clubs')
# Out:
# Text(0.5, 0, 'Clubs')

# %%
df['Position'].value_counts().head(5).plot(kind='pie',autopct="%0.2f%%")
# Out:
# <AxesSubplot:ylabel='Position'>

# %%
df['Position'].value_counts()
# Out:
# DF       178
# MF       108
# FW        81
# FW,MF     47
# GK        42
# MF,FW     36
# DF,MF     15
# MF,DF     13
# DF,FW      6
# FW,DF      6
# Name: Position, dtype: int64

# %%
pd.pivot_table(df[['Goals','Assists','Yellow_Cards']],index = df['Position'],aggfunc = 'sum')
# Out:
#           Assists  Goals  Yellow_Cards
# Position
# DF            136    129           443
# DF,FW           8      3             9
# DF,MF          12     11            36
# FW            172    442           100
# FW,DF           8      8             2
# FW,MF          99    124            72
# GK              2      1            31
# MF            162    171           339
# MF,DF          18     14            42
# MF,FW          68     83            51

# %%
Club_Goals = df.groupby(['Club'])['Goals'].sum().sort_values(ascending=False)
Club_Goals
og = [Club_Goals]
# top_gs = df.groupby(['Name'])['Goals'].sum().sort_values(ascending=False).head(15)

# %%
pd.pivot_table(df[['Goals','Assists','Yellow_Cards']],index = df['Club'],aggfunc = 'sum')
# Out:
#                          Assists  Goals  Yellow_Cards
# Club
# Arsenal                       38     53            49
# Aston Villa                   38     52            71
# Brighton                      24     39            49
# Burnley                       20     32            48
# Chelsea                       38     56            51
# Crystal Palace                29     39            56
# Everton                       32     45            59
# Fulham                        18     26            67
# Leeds United                  45     60            61
# Leicester City                45     64            61
# Liverpool FC                  43     65            40
# Manchester City               55     82            46
# Manchester United             51     70            64
# Newcastle United              26     44            65
# Sheffield United              13     19            73
# Southampton                   33     47            52
# ...

# %%
pd.pivot_table(df[['Goals','Assists']],index = df['Club'],aggfunc = 'sum').plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Club'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="Club",y='Age',data = df)
plt.xticks(rotation=90)
plt.ylabel("Age", rotation=0)
# Out:
# Text(0, 0.5, 'Age')

# %%
df[df['Assists'] >= 10]
# Out:
#                 Name               Club Nationality Position  Age  Matches  \
# 34   Kevin De Bruyne    Manchester City         BEL       MF   29       25
# 51   Bruno Fernandes  Manchester United         POR       MF   25       37
# 161    Son Heung-min  Tottenham Hotspur         KOR       FW   28       37
# 162       Harry Kane  Tottenham Hotspur         ENG       FW   27       35
# 273    Jack Grealish        Aston Villa         ENG    FW,MF   24       26
#
#      Starts  Mins  Goals  Assists  Passes_Attempted  Perc_Passes_Completed  \
# 34       23  1997      6       12              1406                   76.0
# 51       35  3099     18       12              2283                   74.6
# 161      36  3114     17       10              1199                   76.7
# 162      35  3082     23       14               937                   70.1
# 273      24  2185      6       10              1100                   78.5
#
# ...

# %%
#most average age of team
num_player = df.groupby('Club').size()
data = (df.groupby('Club')['Age'].sum())/num_player
data.sort_values(ascending=False)
# Out:
# Club
# Crystal Palace             28.333333
# West Ham United            27.500000
# Burnley                    27.040000
# West Bromwich Albion       26.766667
# Newcastle United           26.074074
# Manchester City            25.708333
# Tottenham Hotspur          25.625000
# Leicester City             25.592593
# Chelsea                    25.592593
# Liverpool FC               25.571429
# Everton                    25.413793
# Leeds United               25.347826
# Fulham                     25.035714
# Arsenal                    24.965517
# Sheffield United           24.814815
# Brighton                   24.555556
# Wolverhampton Wanderers    24.444444
# Aston Villa                24.291667
# Southampton                24.137931
# Manchester United          23.862069
# dtype: float64

# %%
x = df.groupby('Club')['Goals'].sum()
x.sort_values(ascending=False)
# Out:
# Club
# Manchester City            82
# Manchester United          70
# Tottenham Hotspur          66
# Liverpool FC               65
# Leicester City             64
# Leeds United               60
# West Ham United            60
# Chelsea                    56
# Arsenal                    53
# Aston Villa                52
# Southampton                47
# Everton                    45
# Newcastle United           44
# Crystal Palace             39
# Brighton                   39
# Wolverhampton Wanderers    34
# West Bromwich Albion       33
# Burnley                    32
# Fulham                     26
# Sheffield United           19
# Name: Goals, dtype: int64

# %%
Assist_by_club = pd.DataFrame(df.groupby('Club',as_index = False)['Assists'].sum()).sort_values(by='Assists', ascending=False)
Assist_by_club
# Out:
#                        Club  Assists
# 11          Manchester City       55
# 12        Manchester United       51
# 16        Tottenham Hotspur       50
# 18          West Ham United       46
# 8              Leeds United       45
# 9            Leicester City       45
# 10             Liverpool FC       43
# 1               Aston Villa       38
# 0                   Arsenal       38
# 4                   Chelsea       38
# 15              Southampton       33
# 6                   Everton       32
# 5            Crystal Palace       29
# 13         Newcastle United       26
# 2                  Brighton       24
# 19  Wolverhampton Wanderers       21
# 3                   Burnley       20
# 17     West Bromwich Albion       20
# 7                    Fulham       18
# 14         Sheffield United       13

# %%
Assists_by_clubs = pd.DataFrame(df.groupby('Club',as_index=False)["Assists"].sum())
sns.set_theme(style='whitegrid',color_codes=True)
ax = sns.barplot(x='Club',y='Assists',data=Assists_by_clubs.sort_values(by='Assists'),palette = "Set2")
ax.set_xlabel('Club',fontsize=30)
ax.set_ylabel('Assists',fontsize=20)
plt.xticks(rotation=70)
plt.rcParams["figure.figsize"]=(10,12)
plt.title("Plot of Clubs vs Total Assists ", fontsize=20)
plt.show()

# %%
Assist_by_club = pd.DataFrame(df.groupby('Club',as_index = False)['Assists'].sum())
Assist_by_club
# Out:
#                        Club  Assists
# 0                   Arsenal       38
# 1               Aston Villa       38
# 2                  Brighton       24
# 3                   Burnley       20
# 4                   Chelsea       38
# 5            Crystal Palace       29
# 6                   Everton       32
# 7                    Fulham       18
# 8              Leeds United       45
# 9            Leicester City       45
# 10             Liverpool FC       43
# 11          Manchester City       55
# 12        Manchester United       51
# 13         Newcastle United       26
# 14         Sheffield United       13
# 15              Southampton       33
# 16        Tottenham Hotspur       50
# 17     West Bromwich Albion       20
# 18          West Ham United       46
# 19  Wolverhampton Wanderers       21

# %%
df[df['Assists']==df['Assists'].max()]
# Out:
#            Name               Club Nationality Position  Age  Matches  Starts  \
# 162  Harry Kane  Tottenham Hotspur         ENG       FW   27       35      35
#
#      Mins  Goals  Assists  Passes_Attempted  Perc_Passes_Completed  \
# 162  3082     23       14               937                   70.1
#
#      Penalty_Goals  Penalty_Attempted   xG    xA  Yellow_Cards  Red_Cards  \
# 162              4                  4  0.6  0.22             1          0
#
#      MinsPerMatch  Goals_Per_Match
# 162     88.057143         0.657143

# %%
Goals_by_clubs = pd.DataFrame(df.groupby('Club', as_index=False)["Goals"].sum())
sns.set_theme(style='whitegrid', color_codes=True)
ax = sns.barplot(x='Club', y='Goals', data=Goals_by_clubs.sort_values(by="Goals") , palette="rocket")
ax.set_xlabel("Club", fontsize=20)
ax.set_ylabel("Goals", fontsize=20)
plt.xticks(rotation=70)
plt.rcParams["figure.figsize"] = (12,6)
plt.title("Plot of Clubs vs Total Goals ", fontsize=20)
plt.show()

# %%
#top 10 players scored goals
top_10_goals = df[['Name' , 'Club','Goals','Matches']].sort_values(by='Goals',ascending=False).head(10)
top_10_goals=top_10_goals.reset_index(drop=True)
top_10_goals
# Out:
#                     Name               Club  Goals  Matches
# 0             Harry Kane  Tottenham Hotspur     23       35
# 1          Mohamed Salah       Liverpool FC     22       37
# 2        Bruno Fernandes  Manchester United     18       37
# 3        Patrick Bamford       Leeds United     17       38
# 4          Son Heung-min  Tottenham Hotspur     17       37
# 5  Dominic Calvert-Lewin            Everton     16       33
# 6            Jamie Vardy     Leicester City     15       34
# 7          Ollie Watkins        Aston Villa     14       37
# 8         İlkay Gündoğan    Manchester City     13       28
# 9    Alexandre Lacazette            Arsenal     13       31

# %%
top_10_goals_per_match  = df[['Name','Goals','Goals_Per_Match']].nlargest(n=10,columns = "Goals_Per_Match")
top_10_goals_per_match = top_10_goals_per_match.reset_index(drop=True)
top_10_goals_per_match
# Out:
#                     Name  Goals  Goals_Per_Match
# 0             Harry Kane     23         0.657143
# 1          Mohamed Salah     22         0.594595
# 2            Joe Willock      8         0.571429
# 3          Jesse Lingard      9         0.562500
# 4            Gareth Bale     11         0.550000
# 5         Anthony Elanga      1         0.500000
# 6        Bruno Fernandes     18         0.486486
# 7  Dominic Calvert-Lewin     16         0.484848
# 8      Kelechi Iheanacho     12         0.480000
# 9             Diogo Jota      9         0.473684

# %%
#Piechart - goals with assist and without assist
plt.figure(figsize=(14,7))
Total_goals = df['Goals'].sum()
assists = df['Assists'].sum()
data = [Total_goals-assists ,assists]
labels = ['Goals without assists','Goals with assists']
color  = sns.color_palette("Set2")
plt.pie(data , labels = labels , colors = color,autopct = "%0.1f%%")
plt.show()

# %%
df['Total_Cards'] = df['Yellow_Cards'] + df['Red_Cards']
Total_cards = pd.DataFrame(df.groupby('Club',as_index=False)['Total_Cards'].sum()).sort_values(by='Total_Cards',ascending=False)
Total_cards.reset_index(drop=True)

# Goals_by_clubs = pd.DataFrame(df.groupby('Club', as_index=False)["Goals"].sum())
# Out:
#                        Club  Total_Cards
# 0          Sheffield United           76
# 1               Aston Villa           75
# 2                    Fulham           70
# 3          Newcastle United           68
# 4         Manchester United           65
# 5              Leeds United           62
# 6                   Everton           61
# 7            Leicester City           61
# 8         Tottenham Hotspur           59
# 9            Crystal Palace           58
# 10  Wolverhampton Wanderers           56
# 11                 Brighton           55
# 12     West Bromwich Albion           55
# 13              Southampton           55
# 14                  Arsenal           54
# 15                  Chelsea           54
# 16          West Ham United           53
# 17          Manchester City           48
# 18                  Burnley           48
# 19             Liverpool FC           40

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Club',y='Total_Cards',data = Total_cards)
sns.set_theme(style='whitegrid', color_codes=True)
plt.xticks(rotation=90)
plt.show()

# %%
df.corr()
# Out:
#                             Age   Matches    Starts      Mins     Goals  \
# Age                    1.000000  0.149628  0.156387  0.158643  0.047022
# Matches                0.149628  1.000000  0.938116  0.947351  0.441977
# Starts                 0.156387  0.938116  1.000000  0.997031  0.405381
# Mins                   0.158643  0.947351  0.997031  1.000000  0.400398
# Goals                  0.047022  0.441977  0.405381  0.400398  1.000000
# Assists                0.026740  0.508009  0.477704  0.474677  0.617831
# Passes_Attempted       0.120244  0.785362  0.853448  0.855600  0.201526
# Perc_Passes_Completed  0.122812  0.085462  0.086039  0.085460 -0.025137
# Penalty_Goals          0.084547  0.227929  0.216877  0.219027  0.594730
# Penalty_Attempted      0.083328  0.234389  0.221418  0.224115  0.590492
# xG                    -0.056098  0.192047  0.072487  0.075016  0.681959
# xA                    -0.047849  0.227570  0.113446  0.117602  0.348428
# ...

# %%
corr_df = df.corr(method = 'pearson')
plt.figure(figsize=(20,10))
heatmap = sns.heatmap(corr_df,annot=True,fmt='.1g',vmin= -1 ,vmax = 1, center = 0, cmap = 'inferno',linewidths=1,linecolor='Black')
heatmap.set_title('Correlation HeatMشp Between Variable')
heatmap.set_xticklabels(heatmap.get_xticklabels(),rotation = 90)
# Out:
# [Text(0.5, 0, 'Age'),
#  Text(1.5, 0, 'Matches'),
#  Text(2.5, 0, 'Starts'),
#  Text(3.5, 0, 'Mins'),
#  Text(4.5, 0, 'Goals'),
#  Text(5.5, 0, 'Assists'),
#  Text(6.5, 0, 'Passes_Attempted'),
#  Text(7.5, 0, 'Perc_Passes_Completed'),
#  Text(8.5, 0, 'Penalty_Goals'),
#  Text(9.5, 0, 'Penalty_Attempted'),
#  Text(10.5, 0, 'xG'),
#  Text(11.5, 0, 'xA'),
#  Text(12.5, 0, 'Yellow_Cards'),
#  Text(13.5, 0, 'Red_Cards'),
#  Text(14.5, 0, 'MinsPerMatch'),
#  Text(15.5, 0, 'Goals_Per_Match'),
#  Text(16.5, 0, 'Total_Cards')]
